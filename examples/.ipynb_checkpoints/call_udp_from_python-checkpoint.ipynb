# %% [markdown]
# # Examples on how to execute UDP (User Defined Processes)
# This script explains how to use UDP's designed in the PEOPLE project. <br>
# The UDP's always give back a DataCube or a VectorCube (specified in the description of the UDP) <br>
# <br>

# %%
import openeo

# %%
# additional imports for visualization and checks
from shapely.geometry import shape
import rasterio
from rasterio.plot import show, show_hist
from matplotlib import pyplot

# %%
# establish connection to OpenEO and authenticate
connection = openeo.connect("openeo-dev.vito.be").authenticate_oidc()
# Out:
# Authenticated using refresh token.

# %%
# specify the geometry --> here we just hardcode Luxemburg
polygon =  {"type": "Polygon", 
            "coordinates": [
                [[6.234, 49.9], [6.245, 49.897], [6.268, 49.889], [6.294, 49.879], [6.313, 49.873], [6.343, 49.865], 
                 [6.392, 49.849], [6.399, 49.847], [6.44, 49.834], [6.452, 49.828], [6.47, 49.823], [6.474, 49.82], 
                 [6.47, 49.802], [6.467, 49.794], [6.455, 49.765], [6.448, 49.743], [6.433, 49.698], [6.418, 49.653], 
                 [6.407, 49.627], [6.403, 49.619], [6.399, 49.603], [6.399, 49.6], [6.395, 49.592], [6.384, 49.558], 
                 [6.38, 49.55], [6.369, 49.473], [6.365, 49.471], [6.339, 49.471], [6.328, 49.471], [6.324, 49.473], 
                 [6.275, 49.476], [6.257, 49.476], [6.215, 49.478], [6.174, 49.481], [6.144, 49.481], [6.129, 49.484], 
                 [6.125, 49.484], [6.058, 49.486], [6.009, 49.489], [5.998, 49.492], [5.964, 49.492], [5.957, 49.494], 
                 [5.942, 49.494], [5.897, 49.497], [5.893, 49.497], [5.844, 49.529], [5.829, 49.539], [5.818, 49.547], 
                 [5.829, 49.571], [5.859, 49.643], [5.87, 49.672], [5.87, 49.675], [5.885, 49.709], [5.874, 49.72], 
                 [5.874, 49.722], [5.848, 49.749], [5.803, 49.794], [5.754, 49.844], [5.747, 49.852], [5.747, 49.855], 
                 [5.754, 49.863], [5.758, 49.865], [5.762, 49.871], [5.762, 49.873], [5.769, 49.881], [5.773, 49.884], 
                 [5.773, 49.887], [5.803, 49.918], [5.829, 49.953], [5.863, 49.99], [5.964, 50.109], [6.024, 50.183], 
                 [6.069, 50.162], [6.08, 50.157], [6.114, 50.141], [6.137, 50.13], [6.144, 50.112], [6.163, 50.072], 
                 [6.182, 50.027], [6.189, 50.011], [6.193, 49.998], [6.2, 49.982], [6.215, 49.95], [6.219, 49.94], 
                 [6.223, 49.926], [6.227, 49.921], [6.227, 49.918], [6.23, 49.91], [6.234, 49.9]]
            ]
           }

# %%
# show the extent Luxemburg at NUTS level-0
shape(polygon)
# Out:
# <POLYGON ((6.234 49.9, 6.245 49.897, 6.268 49.889, 6.294 49.879, 6.313 49.87...>

# %% [markdown]
# ## FCOVER dataset in original resolution and projection

# %%
cube = connection.datacube_from_process(
    process_id="udp_annual_avg_fcover",
    namespace="https://raw.githubusercontent.com/integratedmodelling/OpenEO-UDP-UDF-catalogue/main/UDP/json/udp_annual_avg_fcover.json",
    geometry=polygon,   
    year=2020)
# Out:
# C:\Users\BUCHHORM\Anaconda3\envs\people\lib\site-packages\openeo\metadata.py:255: UserWarning: No cube:dimensions metadata
#   complain("No cube:dimensions metadata")

# %%
# since the result is a single file we do not need a batch job - synchronous request
# %time cube.download(r'./FCOVER_annual-average_2020.tif')
# Out:
# Wall time: 1min 2s

# %%
# visu result
with rasterio.open("FCOVER_annual-average_2020.tif") as src:
    fig, (axrgb, axhist) = pyplot.subplots(1, 2, figsize=(14,7))
    show(src, with_bounds=True, ax=axrgb, title='annual avg FCOVER year 2020')
    show_hist(src, bins=50, lw=0.0, stacked=False, alpha=0.3, histtype='stepfilled', title="Histogram", ax=axhist)
    pyplot.show()

# %% [markdown]
# ## reprojected FCOVER dataset (EPSG: 3035, 100m spatial resolution)

# %%
cube2 = connection.datacube_from_process(
    process_id="udp_annual_avg_fcover",
    namespace="https://raw.githubusercontent.com/integratedmodelling/OpenEO-UDP-UDF-catalogue/main/UDP/json/udp_annual_avg_fcover.json",
    geometry=polygon,   
    year=2020,
    output_warp=True,
    output_epsg=3035,
    resolution=100)

# %%
# in this call we will use the asynchronous data handling
# %time cube2.execute_batch(r'./FCOVER_annual-average_2020_100m_EPSG3035.tif')
# Out:
# 0:00:00 Job 'j-7ed5fbb8ef254c1cbee3db6470a598e8': send 'start'
# 0:00:21 Job 'j-7ed5fbb8ef254c1cbee3db6470a598e8': queued (progress N/A)
# 0:00:27 Job 'j-7ed5fbb8ef254c1cbee3db6470a598e8': queued (progress N/A)
# 0:00:33 Job 'j-7ed5fbb8ef254c1cbee3db6470a598e8': queued (progress N/A)
# 0:00:42 Job 'j-7ed5fbb8ef254c1cbee3db6470a598e8': queued (progress N/A)
# 0:00:52 Job 'j-7ed5fbb8ef254c1cbee3db6470a598e8': queued (progress N/A)
# 0:01:04 Job 'j-7ed5fbb8ef254c1cbee3db6470a598e8': queued (progress N/A)
# 0:01:19 Job 'j-7ed5fbb8ef254c1cbee3db6470a598e8': queued (progress N/A)
# 0:01:39 Job 'j-7ed5fbb8ef254c1cbee3db6470a598e8': queued (progress N/A)
# 0:02:03 Job 'j-7ed5fbb8ef254c1cbee3db6470a598e8': running (progress N/A)
# 0:02:33 Job 'j-7ed5fbb8ef254c1cbee3db6470a598e8': running (progress N/A)
# 0:03:10 Job 'j-7ed5fbb8ef254c1cbee3db6470a598e8': running (progress N/A)
# 0:04:19 Job 'j-7ed5fbb8ef254c1cbee3db6470a598e8': finished (progress N/A)
# Wall time: 4min 20s
# <BatchJob job_id='j-7ed5fbb8ef254c1cbee3db6470a598e8'>

# %%
# visu result
with rasterio.open("FCOVER_annual-average_2020_100m_EPSG3035.tif") as src:
    fig, (axrgb, axhist) = pyplot.subplots(1, 2, figsize=(14,7))
    show(src, with_bounds=True, ax=axrgb, title='annual avg FCOVER year 2020 reprojected')
    show_hist(src, bins=50, lw=0.0, stacked=False, alpha=0.3, histtype='stepfilled', title="Histogram", ax=axhist)
    pyplot.show()

# %% [markdown]
# ## arable/non-arable mask based on Corine ACC
# reprojected to EPSG:3035 and 100m resolution

# %%
# prepare parameters for the UDP
# Note: theoretically not needed since we have a default dict --> but lets change the values to show its usage
remapping_dict = {141: 1, 211: 2, 212: 2, 213: 2, 221: 1, 222: 1, 223: 1, 231: 1, 241: 1, 242: 1, 243: 1, 
                  244: 1, 311: 1, 312: 1, 313: 1, 321: 1, 322: 1, 323: 1, 324: 1, 333: 1, 334: 1}

# %%
cube3 = connection.datacube_from_process(
    process_id="udp_CORINE_arable_mask",
    namespace="https://raw.githubusercontent.com/integratedmodelling/OpenEO-UDP-UDF-catalogue/main/UDP/json/udp_corine_arable_mask.json",
    geometry=polygon,   
    year=2020,
    remapping_dict=remapping_dict,
    output_warp=True,
    output_epsg=3035,
    resolution=100)

# %%
# again, we need no batch job to downlad a single file
# %time cube3.download(r'./arable-mask_2020_100m_EPSG3035.tif')
# Out:
# ---------------------------------------------------------------------------
# OpenEoApiError                            Traceback (most recent call last)
# <timed eval> in <module>
#
# ~\Anaconda3\envs\people\lib\site-packages\openeo\rest\datacube.py in download(self, outputfile, format, options)
#    1945             format = guess_format(outputfile)
#    1946         cube = self._ensure_save_result(format=format, options=options)
# -> 1947         return self._connection.download(cube.flat_graph(), outputfile)
#    1948
#    1949     def validate(self) -> List[dict]:
#
# ~\Anaconda3\envs\people\lib\site-packages\openeo\rest\connection.py in download(self, graph, outputfile, timeout)
#    1285         """
#    1286         request = self._build_request_with_process_graph(process_graph=graph)
# -> 1287         response = self.post(path="/result", json=request, expected_status=200, stream=True, timeout=timeout)
#    1288
#    1289         if outputfile is not None:
#
# ~\Anaconda3\envs\people\lib\site-packages\openeo\rest\connection.py in post(self, path, json, **kwargs)
#     175         :return: response: Response
#     176         """
# --> 177         return self.request("post", path=path, json=json, allow_redirects=False, **kwargs)
#     178
#     179     def delete(self, path, **kwargs) -> Response:
#
# ~\Anaconda3\envs\people\lib\site-packages\openeo\rest\connection.py in request(self, method, path, headers, auth, check_error, expected_status, **kwargs)
#     612         try:
#     613             # Initial request attempt
# --> 614             return _request()
#     615         except OpenEoApiError as api_exc:
#     616             if api_exc.http_status_code == 403 and api_exc.code == "TokenInvalid":
#
# ~\Anaconda3\envs\people\lib\site-packages\openeo\rest\connection.py in _request()
#     605         # Do request, but with retry when access token has expired and refresh token is available.
#     606         def _request():
# --> 607             return super(Connection, self).request(
#     608                 method=method, path=path, headers=headers, auth=auth,
#     609                 check_error=check_error, expected_status=expected_status, **kwargs,
#
# ~\Anaconda3\envs\people\lib\site-packages\openeo\rest\connection.py in request(self, method, path, headers, auth, check_error, expected_status, **kwargs)
#     123         expected_status = ensure_list(expected_status) if expected_status else []
#     124         if check_error and status >= 400 and status not in expected_status:
# --> 125             self._raise_api_error(resp)
#     126         if expected_status and status not in expected_status:
#     127             raise OpenEoRestError("Got status code {s!r} for `{m} {p}` (expected {e!r})".format(
#
# ~\Anaconda3\envs\people\lib\site-packages\openeo\rest\connection.py in _raise_api_error(self, response)
#     154             else:
#     155                 exception = OpenEoApiError(http_status_code=status_code, message=text)
# --> 156         raise exception
#     157
#     158     def get(self, path, stream=False, auth: AuthBase = None, **kwargs) -> Response:
#
# OpenEoApiError: [500] Internal: Server error: UDF Exception during Spark execution:   File "/opt/venv/lib64/python3.8/site-packages/openeo/udf/run_code.py", line 175, in run_udf_code
#     result_cube = func(cube=data.get_datacube_list()[0], context=data.user_context)
#   File "<string>", line 20, in apply_datacube
# ValueError: invalid literal for int() with base 10: 'from_parameter' (ref: r-3cb4f792930e4cda8c95968e12687701)

# %%
# visu result
with rasterio.open("arable-mask_2020_100m_EPSG3035.tif") as src:
    fig, (axrgb, axhist) = pyplot.subplots(1, 2, figsize=(14,7))
    show(src, with_bounds=True, ax=axrgb, title='CORINE arable/non-arable mask 2020 reprojected')
    show_hist(src, bins=50, lw=0.0, stacked=False, alpha=0.3, histtype='stepfilled', title="Histogram", ax=axhist)
    pyplot.show()
